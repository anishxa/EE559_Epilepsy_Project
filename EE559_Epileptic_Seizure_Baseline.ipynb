# %% [markdown]
# ## 1. Download Dataset

# %%
# !curl -s -o Epileptic_Seizure_Recognition.csv https://raw.githubusercontent.com/akshayg056/Epileptic-seizure-detection-/master/data.csv

# %% [markdown]
# ## 2. Data Exploration and Preprocessing
# - Handling missing values
# - Feature scaling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv('Epileptic_Seizure_Recognition.csv')
display(df.head())

# Check for missing values
print('Missing values:', df.isnull().sum().sum())

# Preparing features and labels
# As per the dataset structure, the first column is Unnamed, last column is y (target 1-5)
X = df.drop(columns=[df.columns[0], 'y'])
y = df['y']

# Convert to binary classification (1: Seizure vs 0: Non-Seizure)
y_binary = (y == 1).astype(int)

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print('Data successfully preprocessed and scaled!')
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]
# Missing values: 0
# Data successfully preprocessed and scaled!

# %% [markdown]
# ## 3. Initial Baseline Model Results

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_binary, test_size=0.2, random_state=42)

# Baseline Model: Logistic Regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print('Baseline Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Baseline Accuracy: 0.818695652173913
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      1835
#            1       0.98      0.11      0.19       465
#
#     accuracy                           0.82      2300
#    macro avg       0.90      0.55      0.54      2300
# weighted avg       0.85      0.82      0.75      2300

# %% [markdown]
# ## 4. Challenges Faced and Future Plan
#
# **Challenges Faced:**
# - Interpreting the raw EEG sequence correctly.
# - High-dimensional patterns may not be fully captured by simpler baseline models like Logistic Regression.
# - Class imbalance (Seizure vs Non-Seizure).
#
# **Plan to Address Them:**
# - Implement deep learning architectures (e.g., CNN, RNN, or LSTM) suitable for time-series / sequential data.
# - Apply data augmentation or resampling strategies if the class distribution acts as a bottleneck during training.
# - Use dimensionality reduction techniques (like PCA) to improve interpretability and training stability.
